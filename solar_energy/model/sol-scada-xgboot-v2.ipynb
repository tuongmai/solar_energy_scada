# %%
import itertools

import matplotlib
import xgboost as xgb
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import numpy as np
import time

from dateutil.parser import parse
import pytz

# %%
# process data
data_file_name = "/kaggle/input/sol-scada/2023-07-30_to_2024-06-04.csv"

# Load the solar data
solar_data = pd.read_csv(data_file_name)
data = pd.DataFrame()
data[['date_time', 'power', 'ambient_temparature', 'temparature', 'irradiance']] = solar_data[[
    'DateTime', 
    'Active Power(kW)', 
    'Ambient Temperature(°C)', 
    'Temperature Module1(°C)', 
    'Irradiance(W/m2)'
]]

# remove row where power = 0
data = data[(data['power'] > 0) & (data['power'] < 1000) & (data['irradiance'] > 0)]
MAX = data['power'].max()
print(MAX)
data['power'] = data['power'] / MAX
# Out:
# 868.3506

# %%
# from sklearn.model_selection import train_test_split
# train, test = train_test_split(
#     data, test_size=0.2, random_state=42
# )
# Split the data into a test/train split
data.dropna(how="any", inplace=True)
data = data.sample(frac=1).reset_index(drop=True)
length = len(data)
split_length = int(length * 0.2)
train, test = data[: (length - split_length)], data[(length - split_length) :]
print(train)
# Out:
#                 date_time     power  ambient_temparature  temparature  \
# 0     01/09/2024 15:00:00  0.514848                 37.6         48.0
# 1     09/09/2023 08:30:00  0.147496                 30.8         39.4
# 2     08/30/2023 09:00:00  0.373607                 30.5         40.3
# 3     10/01/2023 06:00:00  0.025845                 25.5         24.0
# 4     02/20/2024 07:00:00  0.076739                 24.1         23.0
# ...                   ...       ...                  ...          ...
# 5640  04/21/2024 10:30:00  0.545487                 36.2         53.1
# 5641  01/07/2024 10:30:00  0.622510                 35.6         50.2
# 5642  09/24/2023 16:00:00  0.079403                 25.3         25.7
# 5643  11/18/2023 08:30:00  0.381776                 26.4         31.9
# 5644  12/25/2023 14:30:00  0.438123                 36.2         54.4
#
#       irradiance
# 0            494
# 1            122
# 2            297
# 3             24
# 4             80
# ...          ...
# 5640         453
# 5641         570
# 5642          68
# 5643         340
# 5644         354
#
# [5645 rows x 5 columns]

# %%
# train model
# Pull apart the independent and dependent variables
train_target = train["power"]
test_target = test["power"]

# Create copies of the DataFrames without modifying the originals
train_copy = train.drop(["date_time", "power"], axis=1).copy()
test_copy = test.drop(["date_time", "power"], axis=1).copy()

# Build XGBoost DMatrix for both train and test with their target variables
train_dmatrix = xgb.DMatrix(train_copy, train_target)
test_dmatrix = xgb.DMatrix(test_copy, test_target)

# Build the XGB parameter list
param = {
    "booster": "gbtree",
    "verbosity": 1,
    "nthread": 12,
    "learning_rate": 0.005,
    "max_depth": 6,
    "subsample": 0.8,
    "lambda": 1.0,
    "objective": "reg:logistic",
    "eval_metric": ["auc", "mae"]
}

# Train the model
eval_list = [(test_dmatrix, "eval"), (train_dmatrix, "train")]
num_round = 10_000
start = time.time()
bst = xgb.train(
    param,
    train_dmatrix,
    num_boost_round=num_round,
    evals=eval_list,
    early_stopping_rounds=20,
)

print(f"Duration: {time.time() - start}s")
# Out:
# [0]	eval-auc:0.84187	eval-mae:0.26004	train-auc:0.83687	train-mae:0.25280
# [1]	eval-auc:0.84259	eval-mae:0.25884	train-auc:0.83768	train-mae:0.25162
# [2]	eval-auc:0.84309	eval-mae:0.25764	train-auc:0.83809	train-mae:0.25044
# [3]	eval-auc:0.84309	eval-mae:0.25646	train-auc:0.83812	train-mae:0.24928
# [4]	eval-auc:0.84316	eval-mae:0.25528	train-auc:0.83818	train-mae:0.24811
# [5]	eval-auc:0.84314	eval-mae:0.25410	train-auc:0.83827	train-mae:0.24696
# [6]	eval-auc:0.84324	eval-mae:0.25293	train-auc:0.83835	train-mae:0.24581
# [7]	eval-auc:0.84327	eval-mae:0.25176	train-auc:0.83838	train-mae:0.24467
# [8]	eval-auc:0.84333	eval-mae:0.25060	train-auc:0.83843	train-mae:0.24353
# [9]	eval-auc:0.84331	eval-mae:0.24944	train-auc:0.83842	train-mae:0.24240
# [10]	eval-auc:0.84329	eval-mae:0.24830	train-auc:0.83843	train-mae:0.24127
# [11]	eval-auc:0.84331	eval-mae:0.24715	train-auc:0.83845	train-mae:0.24015
# [12]	eval-auc:0.84332	eval-mae:0.24601	train-auc:0.83845	train-mae:0.23904
# [13]	eval-auc:0.84335	eval-mae:0.24488	train-auc:0.83847	train-mae:0.23792
# [14]	eval-auc:0.84336	eval-mae:0.24375	train-auc:0.83847	train-mae:0.23682
# [15]	eval-auc:0.84336	eval-mae:0.24263	train-auc:0.83847	train-mae:0.23572
# [16]	eval-auc:0.84337	eval-mae:0.24152	train-auc:0.83848	train-mae:0.23463
# [17]	eval-auc:0.84337	eval-mae:0.24042	train-auc:0.83850	train-mae:0.23354
# [18]	eval-auc:0.84341	eval-mae:0.23932	train-auc:0.83851	train-mae:0.23247
# [19]	eval-auc:0.84360	eval-mae:0.23822	train-auc:0.83868	train-mae:0.23139
# [20]	eval-auc:0.84361	eval-mae:0.23714	train-auc:0.83867	train-mae:0.23032
# [21]	eval-auc:0.84365	eval-mae:0.23605	train-auc:0.83868	train-mae:0.22926
# [22]	eval-auc:0.84371	eval-mae:0.23498	train-auc:0.83877	train-mae:0.22821
# [23]	eval-auc:0.84373	eval-mae:0.23390	train-auc:0.83877	train-mae:0.22715
# [24]	eval-auc:0.84369	eval-mae:0.23284	train-auc:0.83876	train-mae:0.22611
# [25]	eval-auc:0.84369	eval-mae:0.23179	train-auc:0.83876	train-mae:0.22506
# [26]	eval-auc:0.84369	eval-mae:0.23073	train-auc:0.83876	train-mae:0.22403
# [27]	eval-auc:0.84369	eval-mae:0.22968	train-auc:0.83878	train-mae:0.22300
# [28]	eval-auc:0.84368	eval-mae:0.22863	train-auc:0.83878	train-mae:0.22197
# [29]	eval-auc:0.84368	eval-mae:0.22760	train-auc:0.83879	train-mae:0.22096
# [30]	eval-auc:0.84376	eval-mae:0.22657	train-auc:0.83884	train-mae:0.21995
# [31]	eval-auc:0.84375	eval-mae:0.22555	train-auc:0.83883	train-mae:0.21894
# [32]	eval-auc:0.84376	eval-mae:0.22452	train-auc:0.83883	train-mae:0.21794
# [33]	eval-auc:0.84375	eval-mae:0.22351	train-auc:0.83883	train-mae:0.21694
# [34]	eval-auc:0.84377	eval-mae:0.22251	train-auc:0.83883	train-mae:0.21595
# [35]	eval-auc:0.84378	eval-mae:0.22149	train-auc:0.83883	train-mae:0.21497
# [36]	eval-auc:0.84379	eval-mae:0.22050	train-auc:0.83885	train-mae:0.21398
# [37]	eval-auc:0.84380	eval-mae:0.21950	train-auc:0.83885	train-mae:0.21301
# [38]	eval-auc:0.84382	eval-mae:0.21851	train-auc:0.83886	train-mae:0.21204
# [39]	eval-auc:0.84382	eval-mae:0.21754	train-auc:0.83886	train-mae:0.21108
# [40]	eval-auc:0.84381	eval-mae:0.21655	train-auc:0.83886	train-mae:0.21011
# [41]	eval-auc:0.84380	eval-mae:0.21558	train-auc:0.83886	train-mae:0.20916
# [42]	eval-auc:0.84381	eval-mae:0.21462	train-auc:0.83887	train-mae:0.20821
# [43]	eval-auc:0.84380	eval-mae:0.21365	train-auc:0.83887	train-mae:0.20727
# [44]	eval-auc:0.84382	eval-mae:0.21269	train-auc:0.83888	train-mae:0.20633
# [45]	eval-auc:0.84397	eval-mae:0.21174	train-auc:0.83900	train-mae:0.20539
# [46]	eval-auc:0.84397	eval-mae:0.21079	train-auc:0.83901	train-mae:0.20446
# [47]	eval-auc:0.84397	eval-mae:0.20985	train-auc:0.83900	train-mae:0.20354
# [48]	eval-auc:0.84399	eval-mae:0.20891	train-auc:0.83902	train-mae:0.20262
# [49]	eval-auc:0.84398	eval-mae:0.20799	train-auc:0.83902	train-mae:0.20170
# [50]	eval-auc:0.84399	eval-mae:0.20706	train-auc:0.83902	train-mae:0.20079
# [51]	eval-auc:0.84400	eval-mae:0.20614	train-auc:0.83904	train-mae:0.19989
# [52]	eval-auc:0.84400	eval-mae:0.20522	train-auc:0.83904	train-mae:0.19898
# [53]	eval-auc:0.84400	eval-mae:0.20430	train-auc:0.83904	train-mae:0.19808
# [54]	eval-auc:0.84400	eval-mae:0.20339	train-auc:0.83905	train-mae:0.19719
# [55]	eval-auc:0.84401	eval-mae:0.20248	train-auc:0.83906	train-mae:0.19631
# [56]	eval-auc:0.84401	eval-mae:0.20158	train-auc:0.83906	train-mae:0.19543
# [57]	eval-auc:0.84409	eval-mae:0.20069	train-auc:0.83910	train-mae:0.19455
# [58]	eval-auc:0.84409	eval-mae:0.19981	train-auc:0.83910	train-mae:0.19368
# [59]	eval-auc:0.84409	eval-mae:0.19892	train-auc:0.83910	train-mae:0.19281
# [60]	eval-auc:0.84410	eval-mae:0.19805	train-auc:0.83910	train-mae:0.19195
# [61]	eval-auc:0.84410	eval-mae:0.19717	train-auc:0.83910	train-mae:0.19109
# [62]	eval-auc:0.84410	eval-mae:0.19630	train-auc:0.83910	train-mae:0.19024
# [63]	eval-auc:0.84410	eval-mae:0.19543	train-auc:0.83911	train-mae:0.18939
# [64]	eval-auc:0.84410	eval-mae:0.19456	train-auc:0.83911	train-mae:0.18855
# [65]	eval-auc:0.84410	eval-mae:0.19371	train-auc:0.83910	train-mae:0.18771
# [66]	eval-auc:0.84410	eval-mae:0.19286	train-auc:0.83911	train-mae:0.18687
# [67]	eval-auc:0.84410	eval-mae:0.19201	train-auc:0.83911	train-mae:0.18604
# [68]	eval-auc:0.84410	eval-mae:0.19117	train-auc:0.83911	train-mae:0.18521
# [69]	eval-auc:0.84409	eval-mae:0.19033	train-auc:0.83912	train-mae:0.18439
# [70]	eval-auc:0.84409	eval-mae:0.18950	train-auc:0.83912	train-mae:0.18357
# [71]	eval-auc:0.84410	eval-mae:0.18867	train-auc:0.83912	train-mae:0.18276
# [72]	eval-auc:0.84410	eval-mae:0.18785	train-auc:0.83913	train-mae:0.18195
# [73]	eval-auc:0.84410	eval-mae:0.18702	train-auc:0.83913	train-mae:0.18114
# [74]	eval-auc:0.84410	eval-mae:0.18620	train-auc:0.83913	train-mae:0.18034
# [75]	eval-auc:0.84411	eval-mae:0.18539	train-auc:0.83914	train-mae:0.17954
# [76]	eval-auc:0.84412	eval-mae:0.18458	train-auc:0.83914	train-mae:0.17875
# [77]	eval-auc:0.84412	eval-mae:0.18378	train-auc:0.83914	train-mae:0.17796
# [78]	eval-auc:0.84412	eval-mae:0.18298	train-auc:0.83914	train-mae:0.17718
# [79]	eval-auc:0.84412	eval-mae:0.18218	train-auc:0.83914	train-mae:0.17640
# [80]	eval-auc:0.84412	eval-mae:0.18139	train-auc:0.83914	train-mae:0.17563
# [81]	eval-auc:0.84412	eval-mae:0.18060	train-auc:0.83915	train-mae:0.17486
# [82]	eval-auc:0.84413	eval-mae:0.17982	train-auc:0.83917	train-mae:0.17409
# [83]	eval-auc:0.84413	eval-mae:0.17904	train-auc:0.83918	train-mae:0.17334
# [84]	eval-auc:0.84413	eval-mae:0.17826	train-auc:0.83918	train-mae:0.17258
# [85]	eval-auc:0.84414	eval-mae:0.17749	train-auc:0.83918	train-mae:0.17182
# [86]	eval-auc:0.84412	eval-mae:0.17672	train-auc:0.83918	train-mae:0.17107
# [87]	eval-auc:0.84412	eval-mae:0.17595	train-auc:0.83918	train-mae:0.17032
# [88]	eval-auc:0.84412	eval-mae:0.17520	train-auc:0.83919	train-mae:0.16958
# [89]	eval-auc:0.84412	eval-mae:0.17444	train-auc:0.83919	train-mae:0.16884
# [90]	eval-auc:0.84413	eval-mae:0.17370	train-auc:0.83919	train-mae:0.16811
# [91]	eval-auc:0.84413	eval-mae:0.17295	train-auc:0.83919	train-mae:0.16738
# [92]	eval-auc:0.84413	eval-mae:0.17220	train-auc:0.83920	train-mae:0.16665
# [93]	eval-auc:0.84413	eval-mae:0.17146	train-auc:0.83920	train-mae:0.16593
# [94]	eval-auc:0.84413	eval-mae:0.17072	train-auc:0.83920	train-mae:0.16521
# [95]	eval-auc:0.84413	eval-mae:0.16999	train-auc:0.83920	train-mae:0.16450
# [96]	eval-auc:0.84414	eval-mae:0.16927	train-auc:0.83920	train-mae:0.16379
# [97]	eval-auc:0.84414	eval-mae:0.16854	train-auc:0.83924	train-mae:0.16308
# [98]	eval-auc:0.84414	eval-mae:0.16781	train-auc:0.83925	train-mae:0.16238
# [99]	eval-auc:0.84414	eval-mae:0.16710	train-auc:0.83925	train-mae:0.16168
# [100]	eval-auc:0.84414	eval-mae:0.16639	train-auc:0.83926	train-mae:0.16099
# [101]	eval-auc:0.84415	eval-mae:0.16568	train-auc:0.83926	train-mae:0.16029
# [102]	eval-auc:0.84415	eval-mae:0.16497	train-auc:0.83926	train-mae:0.15960
# [103]	eval-auc:0.84415	eval-mae:0.16427	train-auc:0.83927	train-mae:0.15892
# [104]	eval-auc:0.84426	eval-mae:0.16358	train-auc:0.83936	train-mae:0.15824
# [105]	eval-auc:0.84427	eval-mae:0.16289	train-auc:0.83937	train-mae:0.15756
# [106]	eval-auc:0.84428	eval-mae:0.16221	train-auc:0.83937	train-mae:0.15689
# [107]	eval-auc:0.84428	eval-mae:0.16152	train-auc:0.83937	train-mae:0.15622
# [108]	eval-auc:0.84429	eval-mae:0.16084	train-auc:0.83938	train-mae:0.15555
# [109]	eval-auc:0.84430	eval-mae:0.16016	train-auc:0.83940	train-mae:0.15489
# [110]	eval-auc:0.84430	eval-mae:0.15948	train-auc:0.83941	train-mae:0.15423
# [111]	eval-auc:0.84431	eval-mae:0.15882	train-auc:0.83942	train-mae:0.15357
# [112]	eval-auc:0.84430	eval-mae:0.15815	train-auc:0.83942	train-mae:0.15293
# [113]	eval-auc:0.84431	eval-mae:0.15749	train-auc:0.83942	train-mae:0.15227
# [114]	eval-auc:0.84431	eval-mae:0.15682	train-auc:0.83943	train-mae:0.15162
# [115]	eval-auc:0.84431	eval-mae:0.15617	train-auc:0.83944	train-mae:0.15098
# [116]	eval-auc:0.84431	eval-mae:0.15552	train-auc:0.83944	train-mae:0.15035
# [117]	eval-auc:0.84431	eval-mae:0.15487	train-auc:0.83944	train-mae:0.14971
# [118]	eval-auc:0.84431	eval-mae:0.15423	train-auc:0.83944	train-mae:0.14908
# [119]	eval-auc:0.84432	eval-mae:0.15359	train-auc:0.83944	train-mae:0.14845
# [120]	eval-auc:0.84433	eval-mae:0.15295	train-auc:0.83947	train-mae:0.14782
# [121]	eval-auc:0.84436	eval-mae:0.15232	train-auc:0.83948	train-mae:0.14720
# [122]	eval-auc:0.84434	eval-mae:0.15168	train-auc:0.83948	train-mae:0.14659
# [123]	eval-auc:0.84434	eval-mae:0.15105	train-auc:0.83948	train-mae:0.14597
# [124]	eval-auc:0.84439	eval-mae:0.15044	train-auc:0.83951	train-mae:0.14536
# [125]	eval-auc:0.84439	eval-mae:0.14981	train-auc:0.83951	train-mae:0.14475
# [126]	eval-auc:0.84439	eval-mae:0.14919	train-auc:0.83951	train-mae:0.14414
# [127]	eval-auc:0.84439	eval-mae:0.14858	train-auc:0.83952	train-mae:0.14354
# [128]	eval-auc:0.84440	eval-mae:0.14797	train-auc:0.83952	train-mae:0.14294
# [129]	eval-auc:0.84440	eval-mae:0.14736	train-auc:0.83953	train-mae:0.14234
# [130]	eval-auc:0.84441	eval-mae:0.14675	train-auc:0.83953	train-mae:0.14175
# [131]	eval-auc:0.84441	eval-mae:0.14615	train-auc:0.83953	train-mae:0.14116
# [132]	eval-auc:0.84441	eval-mae:0.14555	train-auc:0.83954	train-mae:0.14057
# [133]	eval-auc:0.84445	eval-mae:0.14497	train-auc:0.83955	train-mae:0.13999
# [134]	eval-auc:0.84444	eval-mae:0.14439	train-auc:0.83956	train-mae:0.13942
# [135]	eval-auc:0.84444	eval-mae:0.14380	train-auc:0.83956	train-mae:0.13884
# [136]	eval-auc:0.84444	eval-mae:0.14322	train-auc:0.83956	train-mae:0.13827
# [137]	eval-auc:0.84451	eval-mae:0.14265	train-auc:0.83961	train-mae:0.13771
# [138]	eval-auc:0.84452	eval-mae:0.14207	train-auc:0.83961	train-mae:0.13714
# [139]	eval-auc:0.84453	eval-mae:0.14150	train-auc:0.83962	train-mae:0.13658
# [140]	eval-auc:0.84452	eval-mae:0.14093	train-auc:0.83962	train-mae:0.13601
# [141]	eval-auc:0.84453	eval-mae:0.14037	train-auc:0.83963	train-mae:0.13546
# [142]	eval-auc:0.84454	eval-mae:0.13981	train-auc:0.83963	train-mae:0.13490
# [143]	eval-auc:0.84454	eval-mae:0.13925	train-auc:0.83963	train-mae:0.13435
# [144]	eval-auc:0.84455	eval-mae:0.13869	train-auc:0.83964	train-mae:0.13380
# [145]	eval-auc:0.84456	eval-mae:0.13815	train-auc:0.83964	train-mae:0.13326
# [146]	eval-auc:0.84455	eval-mae:0.13760	train-auc:0.83965	train-mae:0.13272
# [147]	eval-auc:0.84456	eval-mae:0.13705	train-auc:0.83966	train-mae:0.13218
# [148]	eval-auc:0.84456	eval-mae:0.13650	train-auc:0.83967	train-mae:0.13164
# [149]	eval-auc:0.84457	eval-mae:0.13596	train-auc:0.83967	train-mae:0.13110
# [150]	eval-auc:0.84457	eval-mae:0.13542	train-auc:0.83968	train-mae:0.13058
# [151]	eval-auc:0.84456	eval-mae:0.13488	train-auc:0.83968	train-mae:0.13005
# [152]	eval-auc:0.84458	eval-mae:0.13435	train-auc:0.83969	train-mae:0.12953
# [153]	eval-auc:0.84458	eval-mae:0.13382	train-auc:0.83970	train-mae:0.12900
# [154]	eval-auc:0.84457	eval-mae:0.13329	train-auc:0.83971	train-mae:0.12848
# [155]	eval-auc:0.84459	eval-mae:0.13277	train-auc:0.83972	train-mae:0.12797
# [156]	eval-auc:0.84459	eval-mae:0.13224	train-auc:0.83972	train-mae:0.12746
# [157]	eval-auc:0.84460	eval-mae:0.13173	train-auc:0.83973	train-mae:0.12695
# [158]	eval-auc:0.84460	eval-mae:0.13121	train-auc:0.83973	train-mae:0.12644
# [159]	eval-auc:0.84460	eval-mae:0.13069	train-auc:0.83974	train-mae:0.12593
# [160]	eval-auc:0.84461	eval-mae:0.13017	train-auc:0.83975	train-mae:0.12543
# [161]	eval-auc:0.84461	eval-mae:0.12967	train-auc:0.83976	train-mae:0.12493
# [162]	eval-auc:0.84461	eval-mae:0.12916	train-auc:0.83976	train-mae:0.12443
# [163]	eval-auc:0.84460	eval-mae:0.12866	train-auc:0.83976	train-mae:0.12394
# [164]	eval-auc:0.84461	eval-mae:0.12815	train-auc:0.83977	train-mae:0.12344
# [165]	eval-auc:0.84461	eval-mae:0.12766	train-auc:0.83978	train-mae:0.12295
# [166]	eval-auc:0.84462	eval-mae:0.12716	train-auc:0.83979	train-mae:0.12247
# [167]	eval-auc:0.84463	eval-mae:0.12667	train-auc:0.83979	train-mae:0.12198
# [168]	eval-auc:0.84463	eval-mae:0.12618	train-auc:0.83980	train-mae:0.12151
# [169]	eval-auc:0.84463	eval-mae:0.12570	train-auc:0.83980	train-mae:0.12103
# [170]	eval-auc:0.84463	eval-mae:0.12521	train-auc:0.83981	train-mae:0.12055
# [171]	eval-auc:0.84463	eval-mae:0.12473	train-auc:0.83981	train-mae:0.12008
# [172]	eval-auc:0.84464	eval-mae:0.12425	train-auc:0.83981	train-mae:0.11961
# [173]	eval-auc:0.84464	eval-mae:0.12377	train-auc:0.83982	train-mae:0.11914
# [174]	eval-auc:0.84463	eval-mae:0.12329	train-auc:0.83982	train-mae:0.11868
# [175]	eval-auc:0.84463	eval-mae:0.12283	train-auc:0.83983	train-mae:0.11822
# [176]	eval-auc:0.84464	eval-mae:0.12236	train-auc:0.83983	train-mae:0.11775
# [177]	eval-auc:0.84464	eval-mae:0.12189	train-auc:0.83984	train-mae:0.11729
# [178]	eval-auc:0.84464	eval-mae:0.12143	train-auc:0.83984	train-mae:0.11683
# [179]	eval-auc:0.84464	eval-mae:0.12097	train-auc:0.83985	train-mae:0.11639
# [180]	eval-auc:0.84465	eval-mae:0.12050	train-auc:0.83987	train-mae:0.11593
# [181]	eval-auc:0.84465	eval-mae:0.12005	train-auc:0.83987	train-mae:0.11548
# [182]	eval-auc:0.84465	eval-mae:0.11960	train-auc:0.83987	train-mae:0.11504
# [183]	eval-auc:0.84466	eval-mae:0.11915	train-auc:0.83988	train-mae:0.11460
# [184]	eval-auc:0.84467	eval-mae:0.11870	train-auc:0.83988	train-mae:0.11416
# [185]	eval-auc:0.84467	eval-mae:0.11826	train-auc:0.83988	train-mae:0.11372
# [186]	eval-auc:0.84467	eval-mae:0.11781	train-auc:0.83989	train-mae:0.11329
# [187]	eval-auc:0.84467	eval-mae:0.11737	train-auc:0.83989	train-mae:0.11285
# [188]	eval-auc:0.84467	eval-mae:0.11694	train-auc:0.83990	train-mae:0.11242
# [189]	eval-auc:0.84467	eval-mae:0.11651	train-auc:0.83990	train-mae:0.11199
# [190]	eval-auc:0.84467	eval-mae:0.11608	train-auc:0.83990	train-mae:0.11157
# [191]	eval-auc:0.84468	eval-mae:0.11564	train-auc:0.83991	train-mae:0.11115
# [192]	eval-auc:0.84468	eval-mae:0.11521	train-auc:0.83991	train-mae:0.11073
# [193]	eval-auc:0.84468	eval-mae:0.11478	train-auc:0.83992	train-mae:0.11031
# [194]	eval-auc:0.84468	eval-mae:0.11436	train-auc:0.83992	train-mae:0.10989
# [195]	eval-auc:0.84468	eval-mae:0.11393	train-auc:0.83992	train-mae:0.10947
# [196]	eval-auc:0.84468	eval-mae:0.11351	train-auc:0.83992	train-mae:0.10906
# [197]	eval-auc:0.84469	eval-mae:0.11310	train-auc:0.83993	train-mae:0.10865
# [198]	eval-auc:0.84469	eval-mae:0.11268	train-auc:0.83993	train-mae:0.10824
# [199]	eval-auc:0.84469	eval-mae:0.11227	train-auc:0.83994	train-mae:0.10783
# [200]	eval-auc:0.84469	eval-mae:0.11186	train-auc:0.83995	train-mae:0.10743
# [201]	eval-auc:0.84470	eval-mae:0.11146	train-auc:0.83996	train-mae:0.10703
# [202]	eval-auc:0.84470	eval-mae:0.11105	train-auc:0.83996	train-mae:0.10663
# [203]	eval-auc:0.84472	eval-mae:0.11064	train-auc:0.83998	train-mae:0.10624
# [204]	eval-auc:0.84473	eval-mae:0.11024	train-auc:0.83999	train-mae:0.10585
# [205]	eval-auc:0.84472	eval-mae:0.10985	train-auc:0.83999	train-mae:0.10546
# [206]	eval-auc:0.84473	eval-mae:0.10945	train-auc:0.84000	train-mae:0.10507
# [207]	eval-auc:0.84473	eval-mae:0.10907	train-auc:0.84000	train-mae:0.10468
# [208]	eval-auc:0.84473	eval-mae:0.10868	train-auc:0.84001	train-mae:0.10430
# [209]	eval-auc:0.84473	eval-mae:0.10829	train-auc:0.84001	train-mae:0.10392
# [210]	eval-auc:0.84473	eval-mae:0.10791	train-auc:0.84001	train-mae:0.10354
# [211]	eval-auc:0.84473	eval-mae:0.10752	train-auc:0.84002	train-mae:0.10317
# [212]	eval-auc:0.84474	eval-mae:0.10714	train-auc:0.84002	train-mae:0.10279
# [213]	eval-auc:0.84474	eval-mae:0.10676	train-auc:0.84002	train-mae:0.10242
# [214]	eval-auc:0.84474	eval-mae:0.10638	train-auc:0.84003	train-mae:0.10205
# [215]	eval-auc:0.84474	eval-mae:0.10600	train-auc:0.84003	train-mae:0.10168
# [216]	eval-auc:0.84475	eval-mae:0.10563	train-auc:0.84003	train-mae:0.10131
# [217]	eval-auc:0.84475	eval-mae:0.10526	train-auc:0.84004	train-mae:0.10095
# [218]	eval-auc:0.84476	eval-mae:0.10488	train-auc:0.84004	train-mae:0.10059
# [219]	eval-auc:0.84476	eval-mae:0.10451	train-auc:0.84005	train-mae:0.10023
# [220]	eval-auc:0.84476	eval-mae:0.10415	train-auc:0.84005	train-mae:0.09987
# [221]	eval-auc:0.84476	eval-mae:0.10377	train-auc:0.84006	train-mae:0.09951
# [222]	eval-auc:0.84476	eval-mae:0.10341	train-auc:0.84006	train-mae:0.09915
# [223]	eval-auc:0.84476	eval-mae:0.10305	train-auc:0.84006	train-mae:0.09880
# [224]	eval-auc:0.84476	eval-mae:0.10269	train-auc:0.84007	train-mae:0.09845
# [225]	eval-auc:0.84476	eval-mae:0.10234	train-auc:0.84007	train-mae:0.09810
# [226]	eval-auc:0.84476	eval-mae:0.10198	train-auc:0.84007	train-mae:0.09775
# [227]	eval-auc:0.84476	eval-mae:0.10163	train-auc:0.84008	train-mae:0.09741
# [228]	eval-auc:0.84477	eval-mae:0.10128	train-auc:0.84008	train-mae:0.09706
# [229]	eval-auc:0.84476	eval-mae:0.10093	train-auc:0.84008	train-mae:0.09672
# [230]	eval-auc:0.84476	eval-mae:0.10059	train-auc:0.84008	train-mae:0.09639
# [231]	eval-auc:0.84476	eval-mae:0.10024	train-auc:0.84008	train-mae:0.09605
# [232]	eval-auc:0.84476	eval-mae:0.09989	train-auc:0.84009	train-mae:0.09571
# [233]	eval-auc:0.84477	eval-mae:0.09956	train-auc:0.84009	train-mae:0.09538
# [234]	eval-auc:0.84477	eval-mae:0.09922	train-auc:0.84009	train-mae:0.09505
# [235]	eval-auc:0.84477	eval-mae:0.09888	train-auc:0.84009	train-mae:0.09472
# [236]	eval-auc:0.84477	eval-mae:0.09854	train-auc:0.84010	train-mae:0.09439
# [237]	eval-auc:0.84477	eval-mae:0.09821	train-auc:0.84010	train-mae:0.09406
# [238]	eval-auc:0.84478	eval-mae:0.09787	train-auc:0.84010	train-mae:0.09374
# [239]	eval-auc:0.84477	eval-mae:0.09754	train-auc:0.84011	train-mae:0.09341
# [240]	eval-auc:0.84478	eval-mae:0.09721	train-auc:0.84011	train-mae:0.09309
# [241]	eval-auc:0.84478	eval-mae:0.09688	train-auc:0.84011	train-mae:0.09277
# [242]	eval-auc:0.84478	eval-mae:0.09656	train-auc:0.84011	train-mae:0.09246
# [243]	eval-auc:0.84478	eval-mae:0.09624	train-auc:0.84011	train-mae:0.09215
# [244]	eval-auc:0.84478	eval-mae:0.09592	train-auc:0.84012	train-mae:0.09183
# [245]	eval-auc:0.84478	eval-mae:0.09559	train-auc:0.84012	train-mae:0.09152
# [246]	eval-auc:0.84478	eval-mae:0.09528	train-auc:0.84013	train-mae:0.09121
# [247]	eval-auc:0.84478	eval-mae:0.09496	train-auc:0.84013	train-mae:0.09090
# [248]	eval-auc:0.84478	eval-mae:0.09466	train-auc:0.84014	train-mae:0.09060
# [249]	eval-auc:0.84478	eval-mae:0.09434	train-auc:0.84014	train-mae:0.09030
# [250]	eval-auc:0.84478	eval-mae:0.09403	train-auc:0.84014	train-mae:0.08999
# [251]	eval-auc:0.84478	eval-mae:0.09373	train-auc:0.84015	train-mae:0.08969
# [252]	eval-auc:0.84478	eval-mae:0.09342	train-auc:0.84015	train-mae:0.08939
# [253]	eval-auc:0.84479	eval-mae:0.09311	train-auc:0.84015	train-mae:0.08909
# [254]	eval-auc:0.84479	eval-mae:0.09281	train-auc:0.84016	train-mae:0.08880
# [255]	eval-auc:0.84479	eval-mae:0.09251	train-auc:0.84016	train-mae:0.08851
# [256]	eval-auc:0.84479	eval-mae:0.09221	train-auc:0.84016	train-mae:0.08822
# [257]	eval-auc:0.84479	eval-mae:0.09192	train-auc:0.84017	train-mae:0.08792
# [258]	eval-auc:0.84480	eval-mae:0.09162	train-auc:0.84017	train-mae:0.08764
# [259]	eval-auc:0.84480	eval-mae:0.09133	train-auc:0.84017	train-mae:0.08735
# [260]	eval-auc:0.84479	eval-mae:0.09103	train-auc:0.84018	train-mae:0.08706
# [261]	eval-auc:0.84480	eval-mae:0.09075	train-auc:0.84018	train-mae:0.08678
# [262]	eval-auc:0.84480	eval-mae:0.09046	train-auc:0.84018	train-mae:0.08649
# [263]	eval-auc:0.84480	eval-mae:0.09017	train-auc:0.84019	train-mae:0.08621
# [264]	eval-auc:0.84480	eval-mae:0.08989	train-auc:0.84019	train-mae:0.08594
# [265]	eval-auc:0.84480	eval-mae:0.08961	train-auc:0.84019	train-mae:0.08566
# [266]	eval-auc:0.84480	eval-mae:0.08932	train-auc:0.84020	train-mae:0.08538
# [267]	eval-auc:0.84481	eval-mae:0.08904	train-auc:0.84020	train-mae:0.08511
# [268]	eval-auc:0.84481	eval-mae:0.08876	train-auc:0.84020	train-mae:0.08483
# [269]	eval-auc:0.84481	eval-mae:0.08848	train-auc:0.84020	train-mae:0.08456
# [270]	eval-auc:0.84481	eval-mae:0.08821	train-auc:0.84021	train-mae:0.08430
# [271]	eval-auc:0.84482	eval-mae:0.08794	train-auc:0.84021	train-mae:0.08403
# [272]	eval-auc:0.84482	eval-mae:0.08767	train-auc:0.84021	train-mae:0.08376
# [273]	eval-auc:0.84482	eval-mae:0.08741	train-auc:0.84022	train-mae:0.08350
# [274]	eval-auc:0.84482	eval-mae:0.08714	train-auc:0.84022	train-mae:0.08324
# [275]	eval-auc:0.84482	eval-mae:0.08687	train-auc:0.84023	train-mae:0.08298
# [276]	eval-auc:0.84483	eval-mae:0.08660	train-auc:0.84023	train-mae:0.08272
# [277]	eval-auc:0.84483	eval-mae:0.08634	train-auc:0.84023	train-mae:0.08246
# [278]	eval-auc:0.84484	eval-mae:0.08608	train-auc:0.84024	train-mae:0.08220
# [279]	eval-auc:0.84484	eval-mae:0.08583	train-auc:0.84024	train-mae:0.08195
# [280]	eval-auc:0.84484	eval-mae:0.08557	train-auc:0.84025	train-mae:0.08170
# [281]	eval-auc:0.84484	eval-mae:0.08531	train-auc:0.84025	train-mae:0.08144
# [282]	eval-auc:0.84485	eval-mae:0.08505	train-auc:0.84026	train-mae:0.08119
# [283]	eval-auc:0.84484	eval-mae:0.08480	train-auc:0.84026	train-mae:0.08094
# [284]	eval-auc:0.84485	eval-mae:0.08454	train-auc:0.84026	train-mae:0.08069
# [285]	eval-auc:0.84485	eval-mae:0.08429	train-auc:0.84026	train-mae:0.08044
# [286]	eval-auc:0.84485	eval-mae:0.08404	train-auc:0.84027	train-mae:0.08020
# [287]	eval-auc:0.84485	eval-mae:0.08379	train-auc:0.84027	train-mae:0.07995
# [288]	eval-auc:0.84485	eval-mae:0.08355	train-auc:0.84027	train-mae:0.07971
# [289]	eval-auc:0.84485	eval-mae:0.08330	train-auc:0.84028	train-mae:0.07947
# [290]	eval-auc:0.84486	eval-mae:0.08305	train-auc:0.84028	train-mae:0.07922
# [291]	eval-auc:0.84486	eval-mae:0.08282	train-auc:0.84028	train-mae:0.07899
# [292]	eval-auc:0.84486	eval-mae:0.08257	train-auc:0.84029	train-mae:0.07875
# [293]	eval-auc:0.84486	eval-mae:0.08233	train-auc:0.84029	train-mae:0.07851
# [294]	eval-auc:0.84486	eval-mae:0.08210	train-auc:0.84029	train-mae:0.07828
# [295]	eval-auc:0.84487	eval-mae:0.08186	train-auc:0.84029	train-mae:0.07804
# [296]	eval-auc:0.84487	eval-mae:0.08163	train-auc:0.84030	train-mae:0.07781
# [297]	eval-auc:0.84487	eval-mae:0.08140	train-auc:0.84030	train-mae:0.07758
# [298]	eval-auc:0.84487	eval-mae:0.08117	train-auc:0.84030	train-mae:0.07736
# [299]	eval-auc:0.84487	eval-mae:0.08094	train-auc:0.84031	train-mae:0.07713
# [300]	eval-auc:0.84487	eval-mae:0.08071	train-auc:0.84031	train-mae:0.07690
# [301]	eval-auc:0.84488	eval-mae:0.08048	train-auc:0.84031	train-mae:0.07667
# [302]	eval-auc:0.84488	eval-mae:0.08025	train-auc:0.84031	train-mae:0.07645
# [303]	eval-auc:0.84488	eval-mae:0.08003	train-auc:0.84032	train-mae:0.07622
# [304]	eval-auc:0.84488	eval-mae:0.07980	train-auc:0.84032	train-mae:0.07600
# [305]	eval-auc:0.84488	eval-mae:0.07958	train-auc:0.84032	train-mae:0.07578
# [306]	eval-auc:0.84488	eval-mae:0.07936	train-auc:0.84033	train-mae:0.07556
# [307]	eval-auc:0.84488	eval-mae:0.07915	train-auc:0.84033	train-mae:0.07534
# [308]	eval-auc:0.84489	eval-mae:0.07893	train-auc:0.84033	train-mae:0.07512
# [309]	eval-auc:0.84489	eval-mae:0.07871	train-auc:0.84033	train-mae:0.07491
# [310]	eval-auc:0.84489	eval-mae:0.07850	train-auc:0.84034	train-mae:0.07469
# [311]	eval-auc:0.84489	eval-mae:0.07829	train-auc:0.84034	train-mae:0.07448
# [312]	eval-auc:0.84489	eval-mae:0.07808	train-auc:0.84034	train-mae:0.07427
# [313]	eval-auc:0.84489	eval-mae:0.07787	train-auc:0.84034	train-mae:0.07406
# [314]	eval-auc:0.84489	eval-mae:0.07766	train-auc:0.84035	train-mae:0.07385
# [315]	eval-auc:0.84489	eval-mae:0.07745	train-auc:0.84035	train-mae:0.07365
# [316]	eval-auc:0.84489	eval-mae:0.07724	train-auc:0.84035	train-mae:0.07344
# [317]	eval-auc:0.84490	eval-mae:0.07704	train-auc:0.84036	train-mae:0.07323
# [318]	eval-auc:0.84489	eval-mae:0.07683	train-auc:0.84036	train-mae:0.07303
# [319]	eval-auc:0.84490	eval-mae:0.07663	train-auc:0.84036	train-mae:0.07282
# [320]	eval-auc:0.84489	eval-mae:0.07643	train-auc:0.84037	train-mae:0.07262
# [321]	eval-auc:0.84489	eval-mae:0.07624	train-auc:0.84037	train-mae:0.07242
# [322]	eval-auc:0.84489	eval-mae:0.07603	train-auc:0.84037	train-mae:0.07222
# [323]	eval-auc:0.84490	eval-mae:0.07583	train-auc:0.84037	train-mae:0.07202
# [324]	eval-auc:0.84490	eval-mae:0.07563	train-auc:0.84038	train-mae:0.07182
# [325]	eval-auc:0.84490	eval-mae:0.07544	train-auc:0.84038	train-mae:0.07162
# [326]	eval-auc:0.84490	eval-mae:0.07524	train-auc:0.84038	train-mae:0.07143
# [327]	eval-auc:0.84490	eval-mae:0.07505	train-auc:0.84038	train-mae:0.07123
# [328]	eval-auc:0.84490	eval-mae:0.07486	train-auc:0.84039	train-mae:0.07104
# [329]	eval-auc:0.84490	eval-mae:0.07468	train-auc:0.84039	train-mae:0.07085
# [330]	eval-auc:0.84490	eval-mae:0.07449	train-auc:0.84039	train-mae:0.07066
# [331]	eval-auc:0.84490	eval-mae:0.07430	train-auc:0.84039	train-mae:0.07047
# [332]	eval-auc:0.84490	eval-mae:0.07412	train-auc:0.84040	train-mae:0.07028
# [333]	eval-auc:0.84490	eval-mae:0.07393	train-auc:0.84040	train-mae:0.07009
# [334]	eval-auc:0.84490	eval-mae:0.07374	train-auc:0.84040	train-mae:0.06991
# [335]	eval-auc:0.84491	eval-mae:0.07355	train-auc:0.84040	train-mae:0.06972
# [336]	eval-auc:0.84490	eval-mae:0.07337	train-auc:0.84041	train-mae:0.06954
# [337]	eval-auc:0.84490	eval-mae:0.07319	train-auc:0.84041	train-mae:0.06935
# [338]	eval-auc:0.84490	eval-mae:0.07301	train-auc:0.84041	train-mae:0.06917
# [339]	eval-auc:0.84491	eval-mae:0.07283	train-auc:0.84042	train-mae:0.06899
# [340]	eval-auc:0.84491	eval-mae:0.07265	train-auc:0.84042	train-mae:0.06881
# [341]	eval-auc:0.84491	eval-mae:0.07247	train-auc:0.84042	train-mae:0.06862
# [342]	eval-auc:0.84491	eval-mae:0.07229	train-auc:0.84042	train-mae:0.06844
# [343]	eval-auc:0.84491	eval-mae:0.07212	train-auc:0.84043	train-mae:0.06827
# [344]	eval-auc:0.84491	eval-mae:0.07195	train-auc:0.84043	train-mae:0.06809
# [345]	eval-auc:0.84491	eval-mae:0.07177	train-auc:0.84043	train-mae:0.06792
# [346]	eval-auc:0.84492	eval-mae:0.07160	train-auc:0.84043	train-mae:0.06774
# [347]	eval-auc:0.84492	eval-mae:0.07143	train-auc:0.84044	train-mae:0.06757
# [348]	eval-auc:0.84492	eval-mae:0.07126	train-auc:0.84044	train-mae:0.06740
# [349]	eval-auc:0.84492	eval-mae:0.07110	train-auc:0.84044	train-mae:0.06723
# [350]	eval-auc:0.84491	eval-mae:0.07093	train-auc:0.84044	train-mae:0.06706
# [351]	eval-auc:0.84492	eval-mae:0.07076	train-auc:0.84044	train-mae:0.06690
# [352]	eval-auc:0.84492	eval-mae:0.07059	train-auc:0.84045	train-mae:0.06673
# [353]	eval-auc:0.84494	eval-mae:0.07043	train-auc:0.84047	train-mae:0.06656
# [354]	eval-auc:0.84494	eval-mae:0.07026	train-auc:0.84047	train-mae:0.06640
# [355]	eval-auc:0.84494	eval-mae:0.07010	train-auc:0.84047	train-mae:0.06623
# [356]	eval-auc:0.84494	eval-mae:0.06993	train-auc:0.84047	train-mae:0.06607
# [357]	eval-auc:0.84494	eval-mae:0.06978	train-auc:0.84047	train-mae:0.06591
# [358]	eval-auc:0.84494	eval-mae:0.06962	train-auc:0.84048	train-mae:0.06575
# [359]	eval-auc:0.84494	eval-mae:0.06946	train-auc:0.84048	train-mae:0.06559
# [360]	eval-auc:0.84494	eval-mae:0.06930	train-auc:0.84048	train-mae:0.06543
# [361]	eval-auc:0.84495	eval-mae:0.06914	train-auc:0.84048	train-mae:0.06527
# [362]	eval-auc:0.84495	eval-mae:0.06899	train-auc:0.84049	train-mae:0.06511
# [363]	eval-auc:0.84495	eval-mae:0.06883	train-auc:0.84049	train-mae:0.06495
# [364]	eval-auc:0.84495	eval-mae:0.06867	train-auc:0.84049	train-mae:0.06480
# [365]	eval-auc:0.84495	eval-mae:0.06852	train-auc:0.84049	train-mae:0.06464
# [366]	eval-auc:0.84495	eval-mae:0.06836	train-auc:0.84050	train-mae:0.06449
# [367]	eval-auc:0.84495	eval-mae:0.06822	train-auc:0.84050	train-mae:0.06434
# [368]	eval-auc:0.84495	eval-mae:0.06807	train-auc:0.84050	train-mae:0.06419
# [369]	eval-auc:0.84495	eval-mae:0.06791	train-auc:0.84050	train-mae:0.06403
# [370]	eval-auc:0.84496	eval-mae:0.06776	train-auc:0.84051	train-mae:0.06388
# [371]	eval-auc:0.84496	eval-mae:0.06762	train-auc:0.84051	train-mae:0.06373
# [372]	eval-auc:0.84496	eval-mae:0.06747	train-auc:0.84051	train-mae:0.06358
# [373]	eval-auc:0.84496	eval-mae:0.06732	train-auc:0.84051	train-mae:0.06343
# [374]	eval-auc:0.84496	eval-mae:0.06718	train-auc:0.84051	train-mae:0.06329
# [375]	eval-auc:0.84496	eval-mae:0.06703	train-auc:0.84052	train-mae:0.06314
# [376]	eval-auc:0.84496	eval-mae:0.06689	train-auc:0.84052	train-mae:0.06300
# [377]	eval-auc:0.84496	eval-mae:0.06674	train-auc:0.84052	train-mae:0.06286
# [378]	eval-auc:0.84496	eval-mae:0.06660	train-auc:0.84052	train-mae:0.06271
# [379]	eval-auc:0.84496	eval-mae:0.06646	train-auc:0.84052	train-mae:0.06257
# [380]	eval-auc:0.84497	eval-mae:0.06631	train-auc:0.84053	train-mae:0.06243
# [381]	eval-auc:0.84497	eval-mae:0.06618	train-auc:0.84053	train-mae:0.06229
# [382]	eval-auc:0.84497	eval-mae:0.06603	train-auc:0.84053	train-mae:0.06214
# [383]	eval-auc:0.84497	eval-mae:0.06589	train-auc:0.84053	train-mae:0.06200
# [384]	eval-auc:0.84497	eval-mae:0.06576	train-auc:0.84053	train-mae:0.06187
# [385]	eval-auc:0.84497	eval-mae:0.06562	train-auc:0.84054	train-mae:0.06173
# [386]	eval-auc:0.84497	eval-mae:0.06548	train-auc:0.84054	train-mae:0.06159
# [387]	eval-auc:0.84497	eval-mae:0.06535	train-auc:0.84054	train-mae:0.06146
# [388]	eval-auc:0.84497	eval-mae:0.06521	train-auc:0.84054	train-mae:0.06132
# [389]	eval-auc:0.84497	eval-mae:0.06508	train-auc:0.84054	train-mae:0.06118
# [390]	eval-auc:0.84497	eval-mae:0.06495	train-auc:0.84055	train-mae:0.06105
# [391]	eval-auc:0.84497	eval-mae:0.06482	train-auc:0.84055	train-mae:0.06092
# [392]	eval-auc:0.84497	eval-mae:0.06468	train-auc:0.84055	train-mae:0.06079
# [393]	eval-auc:0.84497	eval-mae:0.06455	train-auc:0.84055	train-mae:0.06066
# [394]	eval-auc:0.84497	eval-mae:0.06442	train-auc:0.84055	train-mae:0.06052
# [395]	eval-auc:0.84497	eval-mae:0.06430	train-auc:0.84056	train-mae:0.06039
# [396]	eval-auc:0.84497	eval-mae:0.06417	train-auc:0.84056	train-mae:0.06026
# [397]	eval-auc:0.84497	eval-mae:0.06404	train-auc:0.84056	train-mae:0.06014
# [398]	eval-auc:0.84497	eval-mae:0.06391	train-auc:0.84056	train-mae:0.06001
# [399]	eval-auc:0.84497	eval-mae:0.06378	train-auc:0.84057	train-mae:0.05988
# [400]	eval-auc:0.84497	eval-mae:0.06366	train-auc:0.84057	train-mae:0.05975
# [401]	eval-auc:0.84497	eval-mae:0.06353	train-auc:0.84057	train-mae:0.05963
# [402]	eval-auc:0.84497	eval-mae:0.06341	train-auc:0.84058	train-mae:0.05951
# [403]	eval-auc:0.84497	eval-mae:0.06328	train-auc:0.84058	train-mae:0.05938
# [404]	eval-auc:0.84497	eval-mae:0.06317	train-auc:0.84058	train-mae:0.05926
# [405]	eval-auc:0.84498	eval-mae:0.06305	train-auc:0.84058	train-mae:0.05913
# [406]	eval-auc:0.84497	eval-mae:0.06293	train-auc:0.84059	train-mae:0.05901
# [407]	eval-auc:0.84498	eval-mae:0.06281	train-auc:0.84059	train-mae:0.05889
# [408]	eval-auc:0.84498	eval-mae:0.06270	train-auc:0.84059	train-mae:0.05877
# [409]	eval-auc:0.84498	eval-mae:0.06258	train-auc:0.84059	train-mae:0.05865
# [410]	eval-auc:0.84498	eval-mae:0.06246	train-auc:0.84059	train-mae:0.05854
# [411]	eval-auc:0.84497	eval-mae:0.06235	train-auc:0.84060	train-mae:0.05842
# [412]	eval-auc:0.84498	eval-mae:0.06223	train-auc:0.84060	train-mae:0.05830
# [413]	eval-auc:0.84497	eval-mae:0.06212	train-auc:0.84060	train-mae:0.05819
# [414]	eval-auc:0.84497	eval-mae:0.06200	train-auc:0.84060	train-mae:0.05807
# [415]	eval-auc:0.84497	eval-mae:0.06189	train-auc:0.84061	train-mae:0.05796
# [416]	eval-auc:0.84497	eval-mae:0.06178	train-auc:0.84061	train-mae:0.05784
# [417]	eval-auc:0.84497	eval-mae:0.06167	train-auc:0.84061	train-mae:0.05773
# [418]	eval-auc:0.84497	eval-mae:0.06155	train-auc:0.84061	train-mae:0.05762
# [419]	eval-auc:0.84497	eval-mae:0.06144	train-auc:0.84061	train-mae:0.05751
# [420]	eval-auc:0.84498	eval-mae:0.06133	train-auc:0.84062	train-mae:0.05739
# [421]	eval-auc:0.84498	eval-mae:0.06122	train-auc:0.84063	train-mae:0.05728
# [422]	eval-auc:0.84499	eval-mae:0.06111	train-auc:0.84063	train-mae:0.05717
# [423]	eval-auc:0.84499	eval-mae:0.06100	train-auc:0.84063	train-mae:0.05706
# [424]	eval-auc:0.84499	eval-mae:0.06089	train-auc:0.84063	train-mae:0.05695
# [425]	eval-auc:0.84499	eval-mae:0.06079	train-auc:0.84063	train-mae:0.05684
# [426]	eval-auc:0.84499	eval-mae:0.06068	train-auc:0.84063	train-mae:0.05673
# [427]	eval-auc:0.84499	eval-mae:0.06058	train-auc:0.84064	train-mae:0.05663
# [428]	eval-auc:0.84499	eval-mae:0.06047	train-auc:0.84064	train-mae:0.05652
# [429]	eval-auc:0.84499	eval-mae:0.06037	train-auc:0.84065	train-mae:0.05641
# [430]	eval-auc:0.84499	eval-mae:0.06026	train-auc:0.84065	train-mae:0.05631
# [431]	eval-auc:0.84499	eval-mae:0.06015	train-auc:0.84065	train-mae:0.05620
# [432]	eval-auc:0.84499	eval-mae:0.06005	train-auc:0.84065	train-mae:0.05610
# [433]	eval-auc:0.84499	eval-mae:0.05995	train-auc:0.84065	train-mae:0.05599
# [434]	eval-auc:0.84500	eval-mae:0.05985	train-auc:0.84065	train-mae:0.05589
# [435]	eval-auc:0.84499	eval-mae:0.05975	train-auc:0.84066	train-mae:0.05579
# [436]	eval-auc:0.84500	eval-mae:0.05964	train-auc:0.84066	train-mae:0.05569
# [437]	eval-auc:0.84500	eval-mae:0.05954	train-auc:0.84066	train-mae:0.05558
# [438]	eval-auc:0.84500	eval-mae:0.05944	train-auc:0.84066	train-mae:0.05548
# [439]	eval-auc:0.84500	eval-mae:0.05934	train-auc:0.84066	train-mae:0.05538
# [440]	eval-auc:0.84500	eval-mae:0.05924	train-auc:0.84067	train-mae:0.05528
# [441]	eval-auc:0.84500	eval-mae:0.05914	train-auc:0.84067	train-mae:0.05518
# [442]	eval-auc:0.84500	eval-mae:0.05905	train-auc:0.84067	train-mae:0.05508
# [443]	eval-auc:0.84500	eval-mae:0.05895	train-auc:0.84067	train-mae:0.05498
# [444]	eval-auc:0.84500	eval-mae:0.05886	train-auc:0.84067	train-mae:0.05489
# [445]	eval-auc:0.84500	eval-mae:0.05877	train-auc:0.84067	train-mae:0.05479
# [446]	eval-auc:0.84500	eval-mae:0.05867	train-auc:0.84067	train-mae:0.05469
# [447]	eval-auc:0.84501	eval-mae:0.05858	train-auc:0.84068	train-mae:0.05460
# [448]	eval-auc:0.84501	eval-mae:0.05849	train-auc:0.84068	train-mae:0.05451
# [449]	eval-auc:0.84501	eval-mae:0.05839	train-auc:0.84068	train-mae:0.05441
# [450]	eval-auc:0.84501	eval-mae:0.05830	train-auc:0.84069	train-mae:0.05432
# [451]	eval-auc:0.84501	eval-mae:0.05821	train-auc:0.84069	train-mae:0.05423
# [452]	eval-auc:0.84501	eval-mae:0.05812	train-auc:0.84069	train-mae:0.05414
# [453]	eval-auc:0.84501	eval-mae:0.05803	train-auc:0.84069	train-mae:0.05404
# [454]	eval-auc:0.84501	eval-mae:0.05794	train-auc:0.84069	train-mae:0.05395
# [455]	eval-auc:0.84501	eval-mae:0.05785	train-auc:0.84070	train-mae:0.05386
# [456]	eval-auc:0.84500	eval-mae:0.05776	train-auc:0.84070	train-mae:0.05377
# [457]	eval-auc:0.84501	eval-mae:0.05767	train-auc:0.84070	train-mae:0.05368
# [458]	eval-auc:0.84501	eval-mae:0.05758	train-auc:0.84070	train-mae:0.05359
# [459]	eval-auc:0.84501	eval-mae:0.05749	train-auc:0.84070	train-mae:0.05350
# [460]	eval-auc:0.84501	eval-mae:0.05741	train-auc:0.84070	train-mae:0.05342
# [461]	eval-auc:0.84501	eval-mae:0.05732	train-auc:0.84071	train-mae:0.05333
# [462]	eval-auc:0.84501	eval-mae:0.05723	train-auc:0.84071	train-mae:0.05324
# [463]	eval-auc:0.84501	eval-mae:0.05715	train-auc:0.84071	train-mae:0.05315
# [464]	eval-auc:0.84501	eval-mae:0.05707	train-auc:0.84071	train-mae:0.05307
# [465]	eval-auc:0.84501	eval-mae:0.05699	train-auc:0.84071	train-mae:0.05298
# [466]	eval-auc:0.84501	eval-mae:0.05691	train-auc:0.84071	train-mae:0.05290
# [467]	eval-auc:0.84501	eval-mae:0.05683	train-auc:0.84071	train-mae:0.05281
# [468]	eval-auc:0.84501	eval-mae:0.05674	train-auc:0.84072	train-mae:0.05273
# [469]	eval-auc:0.84501	eval-mae:0.05666	train-auc:0.84072	train-mae:0.05264
# [470]	eval-auc:0.84501	eval-mae:0.05658	train-auc:0.84072	train-mae:0.05256
# [471]	eval-auc:0.84501	eval-mae:0.05650	train-auc:0.84072	train-mae:0.05248
# [472]	eval-auc:0.84502	eval-mae:0.05642	train-auc:0.84072	train-mae:0.05239
# [473]	eval-auc:0.84502	eval-mae:0.05634	train-auc:0.84072	train-mae:0.05231
# [474]	eval-auc:0.84502	eval-mae:0.05626	train-auc:0.84073	train-mae:0.05223
# [475]	eval-auc:0.84502	eval-mae:0.05618	train-auc:0.84073	train-mae:0.05214
# [476]	eval-auc:0.84502	eval-mae:0.05610	train-auc:0.84073	train-mae:0.05206
# [477]	eval-auc:0.84502	eval-mae:0.05602	train-auc:0.84073	train-mae:0.05199
# [478]	eval-auc:0.84502	eval-mae:0.05595	train-auc:0.84073	train-mae:0.05191
# [479]	eval-auc:0.84502	eval-mae:0.05587	train-auc:0.84073	train-mae:0.05183
# [480]	eval-auc:0.84502	eval-mae:0.05579	train-auc:0.84073	train-mae:0.05175
# [481]	eval-auc:0.84502	eval-mae:0.05571	train-auc:0.84074	train-mae:0.05167
# [482]	eval-auc:0.84502	eval-mae:0.05563	train-auc:0.84074	train-mae:0.05159
# [483]	eval-auc:0.84502	eval-mae:0.05555	train-auc:0.84074	train-mae:0.05151
# [484]	eval-auc:0.84502	eval-mae:0.05548	train-auc:0.84074	train-mae:0.05144
# [485]	eval-auc:0.84503	eval-mae:0.05540	train-auc:0.84074	train-mae:0.05136
# [486]	eval-auc:0.84503	eval-mae:0.05533	train-auc:0.84075	train-mae:0.05129
# [487]	eval-auc:0.84503	eval-mae:0.05525	train-auc:0.84075	train-mae:0.05121
# [488]	eval-auc:0.84503	eval-mae:0.05518	train-auc:0.84075	train-mae:0.05114
# [489]	eval-auc:0.84503	eval-mae:0.05511	train-auc:0.84075	train-mae:0.05107
# [490]	eval-auc:0.84503	eval-mae:0.05503	train-auc:0.84075	train-mae:0.05099
# [491]	eval-auc:0.84503	eval-mae:0.05496	train-auc:0.84075	train-mae:0.05092
# [492]	eval-auc:0.84503	eval-mae:0.05489	train-auc:0.84075	train-mae:0.05085
# [493]	eval-auc:0.84504	eval-mae:0.05482	train-auc:0.84076	train-mae:0.05078
# [494]	eval-auc:0.84503	eval-mae:0.05475	train-auc:0.84076	train-mae:0.05070
# [495]	eval-auc:0.84503	eval-mae:0.05468	train-auc:0.84076	train-mae:0.05063
# [496]	eval-auc:0.84503	eval-mae:0.05461	train-auc:0.84076	train-mae:0.05056
# [497]	eval-auc:0.84503	eval-mae:0.05454	train-auc:0.84076	train-mae:0.05048
# [498]	eval-auc:0.84503	eval-mae:0.05446	train-auc:0.84076	train-mae:0.05041
# [499]	eval-auc:0.84503	eval-mae:0.05439	train-auc:0.84077	train-mae:0.05034
# [500]	eval-auc:0.84504	eval-mae:0.05432	train-auc:0.84077	train-mae:0.05027
# [501]	eval-auc:0.84504	eval-mae:0.05426	train-auc:0.84077	train-mae:0.05020
# [502]	eval-auc:0.84504	eval-mae:0.05419	train-auc:0.84077	train-mae:0.05013
# [503]	eval-auc:0.84504	eval-mae:0.05413	train-auc:0.84077	train-mae:0.05006
# [504]	eval-auc:0.84504	eval-mae:0.05406	train-auc:0.84077	train-mae:0.04999
# [505]	eval-auc:0.84504	eval-mae:0.05399	train-auc:0.84078	train-mae:0.04992
# [506]	eval-auc:0.84504	eval-mae:0.05392	train-auc:0.84078	train-mae:0.04985
# [507]	eval-auc:0.84504	eval-mae:0.05386	train-auc:0.84078	train-mae:0.04979
# [508]	eval-auc:0.84504	eval-mae:0.05380	train-auc:0.84078	train-mae:0.04972
# [509]	eval-auc:0.84504	eval-mae:0.05373	train-auc:0.84078	train-mae:0.04965
# [510]	eval-auc:0.84504	eval-mae:0.05367	train-auc:0.84078	train-mae:0.04959
# [511]	eval-auc:0.84504	eval-mae:0.05361	train-auc:0.84079	train-mae:0.04952
# [512]	eval-auc:0.84504	eval-mae:0.05355	train-auc:0.84079	train-mae:0.04946
# [513]	eval-auc:0.84504	eval-mae:0.05348	train-auc:0.84079	train-mae:0.04939
# [514]	eval-auc:0.84504	eval-mae:0.05342	train-auc:0.84079	train-mae:0.04933
# [515]	eval-auc:0.84504	eval-mae:0.05335	train-auc:0.84079	train-mae:0.04926
# [516]	eval-auc:0.84505	eval-mae:0.05329	train-auc:0.84079	train-mae:0.04920
# [517]	eval-auc:0.84504	eval-mae:0.05323	train-auc:0.84080	train-mae:0.04913
# [518]	eval-auc:0.84504	eval-mae:0.05317	train-auc:0.84080	train-mae:0.04907
# [519]	eval-auc:0.84504	eval-mae:0.05311	train-auc:0.84080	train-mae:0.04901
# [520]	eval-auc:0.84504	eval-mae:0.05305	train-auc:0.84080	train-mae:0.04894
# [521]	eval-auc:0.84504	eval-mae:0.05299	train-auc:0.84080	train-mae:0.04888
# [522]	eval-auc:0.84504	eval-mae:0.05293	train-auc:0.84080	train-mae:0.04882
# [523]	eval-auc:0.84505	eval-mae:0.05287	train-auc:0.84080	train-mae:0.04876
# [524]	eval-auc:0.84505	eval-mae:0.05281	train-auc:0.84081	train-mae:0.04870
# [525]	eval-auc:0.84505	eval-mae:0.05275	train-auc:0.84081	train-mae:0.04864
# [526]	eval-auc:0.84504	eval-mae:0.05269	train-auc:0.84081	train-mae:0.04858
# [527]	eval-auc:0.84505	eval-mae:0.05264	train-auc:0.84081	train-mae:0.04852
# [528]	eval-auc:0.84505	eval-mae:0.05258	train-auc:0.84082	train-mae:0.04846
# [529]	eval-auc:0.84504	eval-mae:0.05252	train-auc:0.84082	train-mae:0.04840
# [530]	eval-auc:0.84504	eval-mae:0.05247	train-auc:0.84082	train-mae:0.04834
# [531]	eval-auc:0.84505	eval-mae:0.05241	train-auc:0.84082	train-mae:0.04828
# [532]	eval-auc:0.84505	eval-mae:0.05236	train-auc:0.84082	train-mae:0.04822
# [533]	eval-auc:0.84505	eval-mae:0.05230	train-auc:0.84082	train-mae:0.04817
# [534]	eval-auc:0.84505	eval-mae:0.05224	train-auc:0.84082	train-mae:0.04811
# [535]	eval-auc:0.84505	eval-mae:0.05219	train-auc:0.84083	train-mae:0.04805
# [536]	eval-auc:0.84505	eval-mae:0.05213	train-auc:0.84083	train-mae:0.04799
# [537]	eval-auc:0.84505	eval-mae:0.05207	train-auc:0.84083	train-mae:0.04794
# [538]	eval-auc:0.84505	eval-mae:0.05202	train-auc:0.84083	train-mae:0.04788
# [539]	eval-auc:0.84505	eval-mae:0.05197	train-auc:0.84083	train-mae:0.04783
# [540]	eval-auc:0.84505	eval-mae:0.05191	train-auc:0.84083	train-mae:0.04777
# [541]	eval-auc:0.84505	eval-mae:0.05186	train-auc:0.84083	train-mae:0.04771
# [542]	eval-auc:0.84505	eval-mae:0.05181	train-auc:0.84084	train-mae:0.04766
# [543]	eval-auc:0.84505	eval-mae:0.05176	train-auc:0.84084	train-mae:0.04760
# [544]	eval-auc:0.84505	eval-mae:0.05170	train-auc:0.84084	train-mae:0.04755
# [545]	eval-auc:0.84505	eval-mae:0.05165	train-auc:0.84084	train-mae:0.04750
# [546]	eval-auc:0.84505	eval-mae:0.05160	train-auc:0.84084	train-mae:0.04744
# [547]	eval-auc:0.84505	eval-mae:0.05155	train-auc:0.84084	train-mae:0.04739
# [548]	eval-auc:0.84505	eval-mae:0.05150	train-auc:0.84085	train-mae:0.04734
# [549]	eval-auc:0.84505	eval-mae:0.05145	train-auc:0.84085	train-mae:0.04729
# [550]	eval-auc:0.84505	eval-mae:0.05140	train-auc:0.84085	train-mae:0.04724
# [551]	eval-auc:0.84505	eval-mae:0.05134	train-auc:0.84085	train-mae:0.04719
# [552]	eval-auc:0.84505	eval-mae:0.05130	train-auc:0.84085	train-mae:0.04714
# [553]	eval-auc:0.84505	eval-mae:0.05125	train-auc:0.84085	train-mae:0.04708
# [554]	eval-auc:0.84506	eval-mae:0.05120	train-auc:0.84085	train-mae:0.04703
# [555]	eval-auc:0.84506	eval-mae:0.05115	train-auc:0.84086	train-mae:0.04698
# [556]	eval-auc:0.84505	eval-mae:0.05110	train-auc:0.84086	train-mae:0.04693
# [557]	eval-auc:0.84506	eval-mae:0.05105	train-auc:0.84086	train-mae:0.04688
# [558]	eval-auc:0.84505	eval-mae:0.05100	train-auc:0.84086	train-mae:0.04683
# [559]	eval-auc:0.84505	eval-mae:0.05095	train-auc:0.84086	train-mae:0.04678
# [560]	eval-auc:0.84505	eval-mae:0.05091	train-auc:0.84086	train-mae:0.04673
# [561]	eval-auc:0.84506	eval-mae:0.05086	train-auc:0.84087	train-mae:0.04668
# [562]	eval-auc:0.84506	eval-mae:0.05082	train-auc:0.84087	train-mae:0.04663
# [563]	eval-auc:0.84506	eval-mae:0.05077	train-auc:0.84087	train-mae:0.04658
# [564]	eval-auc:0.84506	eval-mae:0.05073	train-auc:0.84088	train-mae:0.04654
# [565]	eval-auc:0.84505	eval-mae:0.05068	train-auc:0.84088	train-mae:0.04649
# [566]	eval-auc:0.84505	eval-mae:0.05063	train-auc:0.84088	train-mae:0.04644
# [567]	eval-auc:0.84506	eval-mae:0.05059	train-auc:0.84088	train-mae:0.04639
# [568]	eval-auc:0.84506	eval-mae:0.05054	train-auc:0.84088	train-mae:0.04635
# [569]	eval-auc:0.84506	eval-mae:0.05049	train-auc:0.84088	train-mae:0.04630
# [570]	eval-auc:0.84506	eval-mae:0.05044	train-auc:0.84088	train-mae:0.04626
# [571]	eval-auc:0.84506	eval-mae:0.05040	train-auc:0.84088	train-mae:0.04621
# [572]	eval-auc:0.84506	eval-mae:0.05036	train-auc:0.84088	train-mae:0.04616
# [573]	eval-auc:0.84506	eval-mae:0.05032	train-auc:0.84089	train-mae:0.04612
# [574]	eval-auc:0.84506	eval-mae:0.05027	train-auc:0.84089	train-mae:0.04607
# [575]	eval-auc:0.84506	eval-mae:0.05023	train-auc:0.84089	train-mae:0.04602
# [576]	eval-auc:0.84506	eval-mae:0.05019	train-auc:0.84089	train-mae:0.04598
# [577]	eval-auc:0.84506	eval-mae:0.05014	train-auc:0.84089	train-mae:0.04593
# [578]	eval-auc:0.84506	eval-mae:0.05010	train-auc:0.84089	train-mae:0.04589
# [579]	eval-auc:0.84506	eval-mae:0.05006	train-auc:0.84090	train-mae:0.04584
# [580]	eval-auc:0.84506	eval-mae:0.05001	train-auc:0.84090	train-mae:0.04580
# [581]	eval-auc:0.84506	eval-mae:0.04997	train-auc:0.84090	train-mae:0.04576
# [582]	eval-auc:0.84506	eval-mae:0.04993	train-auc:0.84090	train-mae:0.04571
# [583]	eval-auc:0.84506	eval-mae:0.04989	train-auc:0.84090	train-mae:0.04567
# [584]	eval-auc:0.84506	eval-mae:0.04984	train-auc:0.84090	train-mae:0.04562
# [585]	eval-auc:0.84506	eval-mae:0.04981	train-auc:0.84090	train-mae:0.04558
# [586]	eval-auc:0.84506	eval-mae:0.04977	train-auc:0.84091	train-mae:0.04554
# [587]	eval-auc:0.84506	eval-mae:0.04972	train-auc:0.84091	train-mae:0.04550
# [588]	eval-auc:0.84507	eval-mae:0.04968	train-auc:0.84091	train-mae:0.04546
# [589]	eval-auc:0.84507	eval-mae:0.04964	train-auc:0.84091	train-mae:0.04541
# [590]	eval-auc:0.84507	eval-mae:0.04961	train-auc:0.84091	train-mae:0.04537
# [591]	eval-auc:0.84507	eval-mae:0.04956	train-auc:0.84091	train-mae:0.04533
# [592]	eval-auc:0.84507	eval-mae:0.04953	train-auc:0.84092	train-mae:0.04529
# [593]	eval-auc:0.84507	eval-mae:0.04949	train-auc:0.84092	train-mae:0.04525
# [594]	eval-auc:0.84507	eval-mae:0.04945	train-auc:0.84092	train-mae:0.04521
# [595]	eval-auc:0.84507	eval-mae:0.04941	train-auc:0.84092	train-mae:0.04517
# [596]	eval-auc:0.84507	eval-mae:0.04937	train-auc:0.84092	train-mae:0.04513
# [597]	eval-auc:0.84507	eval-mae:0.04934	train-auc:0.84092	train-mae:0.04509
# [598]	eval-auc:0.84507	eval-mae:0.04930	train-auc:0.84092	train-mae:0.04505
# [599]	eval-auc:0.84507	eval-mae:0.04926	train-auc:0.84092	train-mae:0.04501
# [600]	eval-auc:0.84507	eval-mae:0.04923	train-auc:0.84092	train-mae:0.04497
# [601]	eval-auc:0.84507	eval-mae:0.04919	train-auc:0.84092	train-mae:0.04493
# [602]	eval-auc:0.84507	eval-mae:0.04915	train-auc:0.84093	train-mae:0.04490
# [603]	eval-auc:0.84507	eval-mae:0.04912	train-auc:0.84093	train-mae:0.04486
# [604]	eval-auc:0.84508	eval-mae:0.04908	train-auc:0.84093	train-mae:0.04482
# [605]	eval-auc:0.84508	eval-mae:0.04905	train-auc:0.84093	train-mae:0.04478
# [606]	eval-auc:0.84508	eval-mae:0.04901	train-auc:0.84093	train-mae:0.04475
# [607]	eval-auc:0.84508	eval-mae:0.04897	train-auc:0.84093	train-mae:0.04471
# [608]	eval-auc:0.84507	eval-mae:0.04894	train-auc:0.84093	train-mae:0.04467
# [609]	eval-auc:0.84507	eval-mae:0.04890	train-auc:0.84093	train-mae:0.04464
# [610]	eval-auc:0.84508	eval-mae:0.04887	train-auc:0.84093	train-mae:0.04460
# [611]	eval-auc:0.84508	eval-mae:0.04883	train-auc:0.84093	train-mae:0.04456
# [612]	eval-auc:0.84508	eval-mae:0.04880	train-auc:0.84094	train-mae:0.04453
# [613]	eval-auc:0.84508	eval-mae:0.04876	train-auc:0.84094	train-mae:0.04449
# [614]	eval-auc:0.84508	eval-mae:0.04873	train-auc:0.84094	train-mae:0.04446
# [615]	eval-auc:0.84508	eval-mae:0.04870	train-auc:0.84094	train-mae:0.04442
# [616]	eval-auc:0.84508	eval-mae:0.04867	train-auc:0.84094	train-mae:0.04439
# [617]	eval-auc:0.84508	eval-mae:0.04863	train-auc:0.84094	train-mae:0.04435
# [618]	eval-auc:0.84508	eval-mae:0.04860	train-auc:0.84094	train-mae:0.04432
# [619]	eval-auc:0.84508	eval-mae:0.04857	train-auc:0.84095	train-mae:0.04428
# [620]	eval-auc:0.84509	eval-mae:0.04853	train-auc:0.84095	train-mae:0.04425
# [621]	eval-auc:0.84509	eval-mae:0.04850	train-auc:0.84095	train-mae:0.04422
# [622]	eval-auc:0.84509	eval-mae:0.04847	train-auc:0.84095	train-mae:0.04418
# [623]	eval-auc:0.84509	eval-mae:0.04844	train-auc:0.84095	train-mae:0.04415
# [624]	eval-auc:0.84509	eval-mae:0.04841	train-auc:0.84096	train-mae:0.04412
# [625]	eval-auc:0.84509	eval-mae:0.04837	train-auc:0.84096	train-mae:0.04408
# [626]	eval-auc:0.84509	eval-mae:0.04834	train-auc:0.84096	train-mae:0.04405
# [627]	eval-auc:0.84509	eval-mae:0.04831	train-auc:0.84096	train-mae:0.04402
# [628]	eval-auc:0.84509	eval-mae:0.04828	train-auc:0.84096	train-mae:0.04398
# [629]	eval-auc:0.84509	eval-mae:0.04825	train-auc:0.84096	train-mae:0.04395
# [630]	eval-auc:0.84509	eval-mae:0.04822	train-auc:0.84096	train-mae:0.04392
# [631]	eval-auc:0.84509	eval-mae:0.04819	train-auc:0.84096	train-mae:0.04389
# [632]	eval-auc:0.84509	eval-mae:0.04816	train-auc:0.84097	train-mae:0.04385
# ...
# [9793]	eval-auc:0.84358	eval-mae:0.04563	train-auc:0.84529	train-mae:0.02715
# [9794]	eval-auc:0.84359	eval-mae:0.04563	train-auc:0.84529	train-mae:0.02715
# [9795]	eval-auc:0.84359	eval-mae:0.04564	train-auc:0.84529	train-mae:0.02714
# [9796]	eval-auc:0.84359	eval-mae:0.04564	train-auc:0.84529	train-mae:0.02714
# [9797]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84529	train-mae:0.02714
# [9798]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9799]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9800]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9801]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9802]	eval-auc:0.84359	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9803]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02714
# [9804]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9805]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9806]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9807]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02713
# [9808]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9809]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9810]	eval-auc:0.84358	eval-mae:0.04564	train-auc:0.84530	train-mae:0.02713
# [9811]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02713
# [9812]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02713
# [9813]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02713
# [9814]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02713
# [9815]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9816]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9817]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9818]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9819]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9820]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9821]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9822]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02712
# [9823]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9824]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9825]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9826]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9827]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9828]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9829]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9830]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9831]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9832]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9833]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9834]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84530	train-mae:0.02711
# [9835]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9836]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9837]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9838]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9839]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9840]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9841]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9842]	eval-auc:0.84359	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02710
# [9843]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9844]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9845]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02710
# [9846]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9847]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9848]	eval-auc:0.84359	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9849]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9850]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9851]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9852]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9853]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9854]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9855]	eval-auc:0.84358	eval-mae:0.04565	train-auc:0.84531	train-mae:0.02709
# [9856]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9857]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9858]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9859]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9860]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9861]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02709
# [9862]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9863]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9864]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9865]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9866]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9867]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9868]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9869]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9870]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9871]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9872]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9873]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9874]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02708
# [9875]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9876]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9877]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9878]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9879]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9880]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84531	train-mae:0.02707
# [9881]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02707
# [9882]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02707
# [9883]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02707
# [9884]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02707
# [9885]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02707
# [9886]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9887]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9888]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9889]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9890]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9891]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9892]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9893]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9894]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9895]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02706
# [9896]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9897]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9898]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9899]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9900]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9901]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9902]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9903]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9904]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9905]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9906]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9907]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02705
# [9908]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9909]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9910]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9911]	eval-auc:0.84357	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9912]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9913]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9914]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9915]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9916]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9917]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9918]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9919]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02704
# [9920]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9921]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9922]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9923]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9924]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9925]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9926]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9927]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9928]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9929]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9930]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84532	train-mae:0.02703
# [9931]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02703
# [9932]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02703
# [9933]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9934]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9935]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9936]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9937]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9938]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9939]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9940]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9941]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9942]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9943]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9944]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9945]	eval-auc:0.84358	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02702
# [9946]	eval-auc:0.84358	eval-mae:0.04566	train-auc:0.84533	train-mae:0.02702
# [9947]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9948]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9949]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9950]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9951]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9952]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9953]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9954]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9955]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9956]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9957]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02701
# [9958]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9959]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9960]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9961]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9962]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9963]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9964]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9965]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9966]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02700
# [9967]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9968]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9969]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9970]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9971]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9972]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9973]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9974]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9975]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9976]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9977]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9978]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84533	train-mae:0.02699
# [9979]	eval-auc:0.84358	eval-mae:0.04567	train-auc:0.84534	train-mae:0.02699
# [9980]	eval-auc:0.84357	eval-mae:0.04567	train-auc:0.84534	train-mae:0.02698
# [9981]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9982]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9983]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9984]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9985]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9986]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9987]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02698
# [9988]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9989]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9990]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9991]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9992]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9993]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9994]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9995]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9996]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9997]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9998]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# [9999]	eval-auc:0.84357	eval-mae:0.04568	train-auc:0.84534	train-mae:0.02697
# Duration: 54.89355683326721s

# %%
pickle.dump(bst, open("/kaggle/working/bst_model_v2.pck", "wb"))

# %%
def plot_model(bst):

    # Plot setup
    sns.set(font_scale=1.25, rc={"figure.figsize": (15, 10)})
    sns.set_style("ticks")  # ticks
    sns.set_palette("colorblind")

    # Plot the importance of each feature
    xgb.plot_importance(bst)
    plt.gcf().subplots_adjust(left=0.15)
    plt.savefig("/kaggle/working/importance.png", bbox_inches="tight")
    clear_plots()

    # Plot setup
    sns.set(font_scale=1.25, rc={"figure.figsize": (20, 10)})
    sns.set_style("whitegrid")  # ticks
    sns.set_palette("colorblind")

    # Plot a decision tree
    matplotlib.rcParams["figure.dpi"] = 1080
    xgb.plot_tree(bst, num_trees=4, rankdir="LR")
    plt.savefig("/kaggle/working/tree.png")
    clear_plots()

# %%
def clear_plots():
    plt.clf()
    import importlib

    importlib.reload(matplotlib)
    importlib.reload(plt)
    importlib.reload(sns)

# %%
origin_test = test

# %%
origin_test = origin_test.sort_values(by='date_time', ascending=False)
print(origin_test)
# Out:
#                 date_time     power  ambient_temparature  temparature  \
# 6247  12/31/2023 16:30:00  0.196038                 25.8         27.2
# 5671  12/31/2023 14:30:00  0.144172                 32.8         37.0
# 6321  12/31/2023 13:00:00  0.557625                 35.2         51.9
# 6932  12/31/2023 09:00:00  0.501718                 35.8         47.5
# 6551  12/30/2023 11:00:00  0.834078                 37.5         62.2
# ...                   ...       ...                  ...          ...
# 6870  01/02/2024 16:00:00  0.208776                 31.4         34.3
# 6557  01/02/2024 15:00:00  0.137659                 33.3         39.0
# 6950  01/02/2024 13:00:00  0.218821                 32.8         40.2
# 6611  01/02/2024 10:30:00  0.670992                 34.0         52.8
# 6173  01/02/2024 09:00:00  0.535827                 31.2         45.9
#
#       irradiance
# 6247         178
# 5671         127
# 6321         771
# 6932         467
# 6551         802
# ...          ...
# 6870         193
# 6557         117
# 6950         203
# 6611         639
# 6173         516
#
# [1411 rows x 5 columns]

# %%
test = origin_test

# How much of a moving average to have
smoothing_step = 750

# Resetting the index to ensure it starts from 0
test.reset_index(drop=True, inplace=True)

# Store dates for plotting output
start_date = test["date_time"][0]
# end_date_index = len(test) - smoothing_step
# end_date = test["date_time"].iloc[end_date_index]
end_date = test["date_time"][smoothing_step - 1]
dates = test["date_time"]

# Format data
test_target = test["power"]
test_copy = test.drop(["date_time", "power"], axis=1).copy()
test_dmatrix = xgb.DMatrix(test_copy)

# Load model and plot it
bst = pickle.load(open("/kaggle/working/bst_model_v2.pck", "rb"))
plot_model(bst)

# Create target vs prediction
pred = bst.predict(test_dmatrix)
actual = test_target

# Scale data from 0-1 to 0-MAX
actual *= MAX
pred *= MAX
print(actual)
# Out:
# 0       170.2299
# 1       125.1918
# 2       484.2136
# 3       435.6673
# 4       724.2724
#           ...
# 1406    181.2909
# 1407    119.5360
# 1408    190.0133
# 1409    582.6565
# 1410    465.2853
# Name: power, Length: 1411, dtype: float64

# %%
# Create a smoothing average
smooth_pred = []
smooth_actual = []
error = 0
for i in range(len(pred)):
    smooth_pred.append(np.mean(pred[i : i + smoothing_step]))
    smooth_actual.append(np.mean(actual[i : i + smoothing_step]))
    error += abs(pred[i] - actual[i])
error /= len(smooth_pred)

# %%
print(error)
# Out:
# 39.66913512378436

# %%
# Line plot setup
sns.set(font_scale=1.25, rc={"figure.figsize": (20, 10)})
sns.set_style("whitegrid")  # ticks
sns.set_palette("colorblind")

# Decrease tick quantity
ax = plt.gca()
ax.xaxis.set_major_locator(plt.MaxNLocator(6))

# Plot lines
sns.lineplot(
    x=dates[: len(dates)], y=smooth_pred, label="Prediction"
)
sns.lineplot(
    x=dates[: len(dates)], y=smooth_actual, label="Actual"
)
plt.xlabel(f"Date")
plt.ylabel(f"Energy Generation (kWh)")
plt.title(
    f"Average Energy Generation Per Day From {end_date} to {start_date}\nAbsolute Error: {error:.2f} kWh"
)
plt.savefig("/kaggle/working/error.png")
clear_plots()

# Scatter plot setup
sns.set(font_scale=1.25, rc={"figure.figsize": (10, 10)})
sns.set_style("whitegrid")  # ticks
sns.set_palette("colorblind")

sns.scatterplot(x=actual, y=pred)
# plt.title("Solar Energy Generation In 30 Minute Intervals")
plt.xlabel("Actual")
plt.ylabel("Predict")
plt.xlim(0.0, MAX)
plt.ylim(0.0, MAX)
x = [np.min(actual), np.max(actual)]
y = x
plt.plot(x, y, 'r')
plt.savefig("/kaggle/working/scatterplot.png")
clear_plots()

# %%
# Line plot setup
sns.set(font_scale=1.25, rc={"figure.figsize": (20, 10)})
sns.set_style("whitegrid")  # ticks
sns.set_palette("colorblind")

# Decrease tick quantity
ax = plt.gca()
ax.xaxis.set_major_locator(plt.MaxNLocator(6))

# Plot lines
sns.lineplot(
    x=dates[: len(dates)], y=pred, label="Prediction"
)
sns.lineplot(
    x=dates[: len(dates)], y=actual, label="Actual"
)
plt.xlabel(f"Date")
plt.ylabel(f"Energy Generation (kWh)")
plt.title("Solar Energy Generation In 30 Minute Intervals")
plt.savefig("/kaggle/working/lineplot.png")
clear_plots()

# %%
# Line plot setup
sns.set(font_scale=1.25, rc={"figure.figsize": (20, 10)})
sns.set_style("whitegrid")  # ticks
sns.set_palette("colorblind")

# Decrease tick quantity
ax = plt.gca()
ax.xaxis.set_major_locator(plt.MaxNLocator(6))

# Plot lines
sns.lineplot(
    x=dates[: 100], y=pred[: 100], label="Prediction"
)
sns.lineplot(
    x=dates[: 100], y=actual[: 100], label="Actual"
)
plt.xlabel(f"Date")
plt.ylabel(f"Energy Generation (kWh)")
plt.title("Solar Energy Generation In 30 Minute Intervals")
plt.savefig("/kaggle/working/lineplot_100.png")
clear_plots()

# %%
from sklearn.metrics import roc_auc_score, roc_curve
# Verification using sklearn's roc_auc_score
def calculate_auc(y_true, y_scores):
    """
    Calculate the AUC given the true labels and predicted scores.

    Parameters:
    y_true (array-like): True binary labels.
    y_scores (array-like): Target scores, can either be probability estimates of the positive class.

    Returns:
    float: AUC score
    """
    # Sort the scores and corresponding true labels
    desc_score_indices = np.argsort(y_scores)[::-1]
    y_true_sorted = np.array(y_true)[desc_score_indices]
    y_scores_sorted = np.array(y_scores)[desc_score_indices]
    
    # Calculate the ROC curve points
    fpr, tpr, _ = roc_curve(y_true_sorted, y_scores_sorted)
    
    # Calculate the AUC using the trapezoidal rule
    auc = np.trapz(tpr, fpr)
    
    return auc

# Example usage
y_true = [0, 0, 1, 1]
y_scores = [0.1, 0.4, 0.35, 0.8]
auc = calculate_auc(y_true, y_scores)
print("AUC:", auc)
# Out:
# AUC: 0.75
